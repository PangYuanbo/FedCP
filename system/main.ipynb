# %%
! python -u main.py -dev cuda -t 1 -jr 1 -nc 5 -nb 10  -algo FedCP -did 0 -lam 5 -gr 1000   -m cnn -data mnist-0.1-npz -dp True -dpl model.feature_extractor
# Out:
# Traceback (most recent call last):
#   File "C:\Users\aaron\PycharmProjects\FedCP\system\main.py", line 127, in <module>
#     print("CUDA \u53ef\u7528")
#   File "C:\Users\aaron\anaconda3\envs\FedAvg\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 5-6: character maps to <undefined>
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch [1/100], Loss: 2.2013
# Epoch [2/100], Loss: 1.8994
# Epoch [3/100], Loss: 1.7330
# Epoch [4/100], Loss: 1.5999
# Epoch [5/100], Loss: 1.5150
# Epoch [6/100], Loss: 1.4510
# Epoch [7/100], Loss: 1.3992
# Epoch [8/100], Loss: 1.3510
# Epoch [9/100], Loss: 1.3081
# Epoch [10/100], Loss: 1.2651
# Epoch [11/100], Loss: 1.2275
# Epoch [12/100], Loss: 1.1899
# Epoch [13/100], Loss: 1.1552
# Epoch [14/100], Loss: 1.1253
# Epoch [15/100], Loss: 1.0935
# Epoch [16/100], Loss: 1.0651
# ...
